# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install xgboost -U 
# !pip uninstall xgboost 
# !pip install xgboost==0.90
# !pip install librosa -U
# !pip install hyperopt
# Out:
# Found existing installation: xgboost 0.90
# Uninstalling xgboost-0.90:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/xgboost-0.90.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/xgboost/*
#     /usr/local/xgboost/libxgboost.so
# Proceed (y/n)? y
#   Successfully uninstalled xgboost-0.90
# Collecting xgboost==0.90
#   Downloading xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8 MB)
#      |████████████████████████████████| 142.8 MB 48 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost==0.90) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost==0.90) (1.21.6)
# Installing collected packages: xgboost
# Successfully installed xgboost-0.90
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Collecting librosa
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      |████████████████████████████████| 213 kB 4.9 MB/s
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.21.6)
# Requirement already satisfied: audioread>=2.1.5 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->librosa) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Installing collected packages: librosa
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# Successfully installed librosa-0.9.1
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.64.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.6.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.21.6)

# %%
import warnings
warnings.simplefilter("ignore", UserWarning)
import os
from tqdm import tqdm
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import librosa
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFECV,mutual_info_regression
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.decomposition import PCA
from xgboost import XGBClassifier

# %%
df = pd.read_csv('/content/drive/MyDrive/A-S-A-M_Major_Project/refined_csv.csv') 
df.head()
# Out:
#    s.no  label  chroma_cens_mean  chroma_cens_var  spectral_contrast_mean  \
# 0     1  blues          0.272263         0.009206               20.523289
# 1     2  blues          0.261079         0.015171               20.672486
# 2     3  blues          0.262717         0.014313               22.191292
# 3     4  blues          0.226096         0.032214               21.423621
# 4     5  blues          0.259727         0.015875               21.459618
#
#    spectral_contrast_var  spectral_flatness_mean  spectral_flatness_var  \
# 0              76.801191                0.004496               0.000030
# 1              67.861845                0.002298               0.000023
# 2              76.122598                0.002635               0.000011
# 3              63.386763                0.000955               0.000003
# 4              63.033892                0.003240               0.000019
#
#    tonnetz_mean  tonnetz_var  ...  mfccs2_mean   mfccs2_var  mfccs3_mean  \
# 0      0.006427     0.004310  ...     0.729792  1201.604492     0.643018
# 1      0.029378     0.004747  ...    -0.191769  2427.744385    -0.095275
# 2      0.024226     0.010467  ...    -0.242961  1260.250732    -0.848506
# 3      0.026663     0.017942  ...    -0.917738  2388.502930    -1.725891
# 4     -0.020944     0.010100  ...    -5.902440  1791.375977    -4.868073
#
#     mfccs3_var  mfccs4_mean   mfccs4_var  mfccs5_mean   mfccs5_var  \
# 0   919.671143     0.427209   743.078430     0.278182   623.940552
# 1  1839.843018    -0.447561  1480.468994    -0.362621  1239.792358
# 2   960.121521    -0.798550   779.632996    -0.909575   656.125000
# 3  1800.508911    -2.034785  1447.093750    -2.367971  1211.789917
# 4  1365.617676    -4.242023  1104.110596    -3.698091   931.020142
#
#    mfccs6_mean   mfccs6_var
# 0     0.075146   538.383850
# 1    -0.517989  1067.379395
# 2    -0.734296   566.632812
# 3    -2.301722  1042.670654
# 4    -3.299158   802.696533
#
# [5 rows x 42 columns]

# %%
corr = df.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, cmap="vlag")

# %%
sol = (corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
                  .stack()
                  .sort_values(ascending=False))
for index, value in sol.items():
    if (value > 0.75) or (value < -0.75):
        print(index, value)
# Out:
# ('mfccs5_var', 'mfccs6_var') 0.9999936679547573
# ('mfccs4_var', 'mfccs5_var') 0.9999910712394249
# ('mfccs3_var', 'mfccs4_var') 0.9999893677149928
# ('mfccs2_var', 'mfccs3_var') 0.9999771822769423
# ('mfccs4_var', 'mfccs6_var') 0.9999740726057749
# ('mfccs3_var', 'mfccs5_var') 0.9999659601771236
# ('mfccs1_var', 'mfccs2_var') 0.9999596953812807
# ('mfccs2_var', 'mfccs4_var') 0.9999423946436026
# ('mfccs3_var', 'mfccs6_var') 0.9999371800298622
# ('mfccs1_var', 'mfccs3_var') 0.9998979780821469
# ('mfccs2_var', 'mfccs5_var') 0.9998975171385978
# ('mfccs_var', 'mfccs1_var') 0.9998686530145339
# ('mfccs2_var', 'mfccs6_var') 0.999852128556924
# ('mfccs1_var', 'mfccs4_var') 0.9998383952660959
# ('mfccs1_var', 'mfccs5_var') 0.999774576830365
# ('mfccs_var', 'mfccs2_var') 0.9997455588083861
# ('mfccs1_var', 'mfccs6_var') 0.9997165966889796
# ('mfccs_var', 'mfccs3_var') 0.9996498002936282
# ('mfccs_var', 'mfccs4_var') 0.9995720353489613
# ('mfccs_var', 'mfccs5_var') 0.9994979351696289
# ('mfccs_var', 'mfccs6_var') 0.9994332870831066
# ('mfccs5_mean', 'mfccs6_mean') 0.9961120091083214
# ('mfccs4_mean', 'mfccs5_mean') 0.9946506323831791
# ('mfccs3_mean', 'mfccs4_mean') 0.9939390444357281
# ('mfccs2_mean', 'mfccs3_mean') 0.9924006860409214
# ('mfccs4_mean', 'mfccs6_mean') 0.9888379212082865
# ('mfccs3_mean', 'mfccs5_mean') 0.9862432824699142
# ('mfccs2_mean', 'mfccs4_mean') 0.981053512841212
# ('mfccs1_mean', 'mfccs2_mean') 0.980197020373264
# ('spec_cent_mean', 'spec_rolloff_mean') 0.9796257234553829
# ('mfccs3_mean', 'mfccs6_mean') 0.9768895444161254
# ('mfccs2_mean', 'mfccs5_mean') 0.9693758472611123
# ('mfccs_mean', 'mfccs1_mean') 0.9684469120758358
# ('mfccs1_mean', 'mfccs3_mean') 0.9622445974829048
# ('mfccs2_mean', 'mfccs6_mean') 0.956426708497237
# ('spec_bw_mean', 'spec_rolloff_mean') 0.956283269811493
# ('mfccs1_mean', 'mfccs4_mean') 0.9447415728179055
# ('mel_spec_mean', 'rms_mean') 0.9444491390296328
# ('chroma_cens_mean', 'chroma_cq_mean') 0.9328394931440186
# ('mfccs1_mean', 'mfccs5_mean') 0.9261291566126214
# ('mfccs_mean', 'mfccs2_mean') 0.9200581295173785
# ('chroma_cens_var', 'tonnetz_var') 0.9119819974867727
# ('mfccs1_mean', 'mfccs6_mean') 0.909871827320756
# ('spec_cent_mean', 'spec_bw_mean') 0.904525186547048
# ('rms_mean', 'poly_feat_mean') 0.9002535474840831
# ('mfccs_mean', 'mfccs3_mean') 0.8933243083846687
# ('spec_bw_var', 'spec_rolloff_var') 0.8849258203728563
# ('spec_cent_mean', 'zero_cross_rate_mean') 0.874710220470835
# ('mfccs_mean', 'mfccs4_mean') 0.8723090788709064
# ('chroma_cens_var', 'chroma_cq_var') 0.8697566241830644
# ('mfccs_mean', 'mfccs5_mean') 0.8502498917104832
# ('spec_cent_var', 'zero_cross_rate_var') 0.8441513264089029
# ('mel_spec_var', 'rms_var') 0.8386210300765359
# ('mfccs_mean', 'mfccs6_mean') 0.8322612550764181
# ('rms_mean', 'mfccs_mean') 0.8201538646362404
# ('spec_cent_var', 'spec_rolloff_var') 0.8156981677883213
# ('rms_mean', 'mfccs1_mean') 0.8047132564200139
# ('mel_spec_mean', 'poly_feat_mean') 0.7935556427394967
# ('poly_feat_mean', 'mfccs_mean') 0.7917395816378627
# ('rms_mean', 'mfccs2_mean') 0.7855248415328132
# ('spectral_flatness_mean', 'spec_cent_mean') 0.781304088673253
# ('poly_feat_mean', 'mfccs1_mean') 0.7802199399452426
# ('spec_rolloff_mean', 'zero_cross_rate_mean') 0.779732444580763
# ('rms_mean', 'mfccs3_mean') 0.767605114333645
# ('poly_feat_mean', 'mfccs2_mean') 0.7659024100960147
# ('mel_spec_mean', 'mel_spec_var') 0.7632189885767547
# ('rms_mean', 'mfccs4_mean') 0.7540475418470518
# ('poly_feat_mean', 'mfccs3_mean') 0.7531262334079909
# ('mfccs2_var', 'mfccs3_mean') -0.7618962591520616
# ('mfccs1_var', 'mfccs3_mean') -0.7619858245540033
# ('mfccs3_mean', 'mfccs3_var') -0.7627342241109029
# ('mfccs3_mean', 'mfccs4_var') -0.7632933060504763
# ('mfccs_var', 'mfccs3_mean') -0.763703376051596
# ('mfccs3_mean', 'mfccs5_var') -0.7640385378224245
# ('mfccs3_mean', 'mfccs6_var') -0.7647953371356853
# ('mfccs2_mean', 'mfccs2_var') -0.7845821879862991
# ('mfccs1_var', 'mfccs2_mean') -0.7845978951624953
# ('mfccs2_mean', 'mfccs3_var') -0.7855129656408146
# ('mfccs2_mean', 'mfccs4_var') -0.7860550448815147
# ('mfccs_var', 'mfccs2_mean') -0.7860810172570518
# ('mfccs2_mean', 'mfccs5_var') -0.7867882981424928
# ('mfccs2_mean', 'mfccs6_var') -0.787520965557721
# ('mfccs1_mean', 'mfccs1_var') -0.8337232338159022
# ('mfccs1_mean', 'mfccs2_var') -0.834324138106428
# ('mfccs_var', 'mfccs1_mean') -0.8345900322036257
# ('mfccs1_mean', 'mfccs3_var') -0.8353438845837964
# ('mfccs1_mean', 'mfccs4_var') -0.8359856012272238
# ('mfccs1_mean', 'mfccs5_var') -0.8367709399490161
# ('mfccs1_mean', 'mfccs6_var') -0.8374585791404311
# ('tonnetz_var', 'chroma_cq_mean') -0.8498101440847716
# ('chroma_cens_mean', 'chroma_cq_var') -0.852072553926265
# ('chroma_cq_mean', 'chroma_cq_var') -0.867990191592889
# ('mfccs_mean', 'mfccs1_var') -0.8781159417131658
# ('mfccs_mean', 'mfccs_var') -0.8782419205461224
# ('mfccs_mean', 'mfccs2_var') -0.8790282027559818
# ('mfccs_mean', 'mfccs3_var') -0.8800866457929487
# ('mfccs_mean', 'mfccs4_var') -0.8807032897340311
# ('mfccs_mean', 'mfccs5_var') -0.8814098975008248
# ('mfccs_mean', 'mfccs6_var') -0.8820002703907173
# ('chroma_cens_mean', 'tonnetz_var') -0.9271595611657302
# ('chroma_cens_var', 'chroma_cq_mean') -0.9431283385262694
# ('chroma_cens_mean', 'chroma_cens_var') -0.9983799435126156
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
y = df.label
X = df
 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=df.label, random_state=77)
X_train.drop('label',axis=1,inplace=True)
X_test.drop('label',axis=1,inplace=True)

# %%
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled, index=X_train.index, columns=X_train.columns)
X_test_scaled = sc.transform(X_test) 
X_test = pd.DataFrame(X_test_scaled, index=X_test.index, columns=X_test.columns)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# %%
estimator = XGBClassifier(eval_metric='merror')
rfecv = RFECV(estimator, step=1, cv=5,scoring='accuracy',verbose=1)
rfecv.fit(X_train, y_train)
# Out:
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# RFECV(cv=5, estimator=XGBClassifier(eval_metric='merror'), scoring='accuracy',
#       verbose=1)

# %%
features_drop_array = list(np.where(rfecv.support_ == False)[0])
X_train.columns[features_drop_array]
# Out:
# Index(['chroma_cens_mean', 'chroma_cens_var', 'spectral_contrast_mean',
#        'spectral_contrast_var', 'spectral_flatness_mean',
#        'spectral_flatness_var', 'tonnetz_mean', 'tonnetz_var',
#        'chroma_stft_mean', 'chroma_stft_var', 'chroma_cq_mean',
#        'chroma_cq_var', 'mel_spec_mean', 'mel_spec_var', 'rms_mean', 'rms_var',
#        'spec_cent_mean', 'spec_cent_var', 'spec_bw_mean', 'spec_bw_var',
#        'spec_rolloff_mean', 'spec_rolloff_var', 'poly_feat_mean',
#        'poly_feat_var', 'zero_cross_rate_mean', 'zero_cross_rate_var',
#        'mfccs_mean', 'mfccs_var', 'mfccs1_mean', 'mfccs1_var', 'mfccs2_mean',
#        'mfccs2_var', 'mfccs3_mean', 'mfccs3_var', 'mfccs4_mean', 'mfccs4_var',
#        'mfccs5_mean', 'mfccs5_var', 'mfccs6_mean', 'mfccs6_var'],
#       dtype='object')

# %%
model = XGBClassifier(n_estimators=1000)
model.fit(X_train,y_train,eval_metric='merror')
# Out:
# XGBClassifier(n_estimators=1000, objective='multi:softprob')

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
target_names = sorted(set(y))
print(target_names)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

pred = pd.DataFrame()
pred["y"] = y_test
pred["PredictedLabel"] = y_pred_test

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

pred1 = pd.DataFrame()
pred1["Y"] = y_train
pred1["Label"] = y_pred_train

# %%
#printing accuracy
print(f'Training accuracy: {accuracy_score(y_train,y_pred_train)}')
print(f'Training:\n {classification_report(y_train, y_pred_train, labels = target_names)}')
#print(f'Training:\n {classification_report(pred1["Y"].astype(str), pred1["Label"].astype(str), labels=target_names)}')
print(f'Testing accuracy: {accuracy_score(y_test,y_pred_test)}')
print(f'Testing:\n {classification_report(y_test, y_pred_test, labels = target_names)}')
#print(f'Testing:\n {classification_report(pred["y"].astype(str), pred["PredictedLabel"].astype(str), labels=target_names)}')
# Out:
# Training accuracy: 1.0
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:604: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-782d11ae1aa4> in <module>()
#       1 #printing accuracy
#       2 print(f'Training accuracy: {accuracy_score(y_train,y_pred_train)}')
# ----> 3 print(f'Training:\n {classification_report(y_train, y_pred_train, labels = target_names)}')
#       4 #print(f'Training:\n {classification_report(pred1["Y"].astype(str), pred1["Label"].astype(str), labels=target_names)}')
#       5 print(f'Testing accuracy: {accuracy_score(y_test,y_pred_test)}')
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2146         average=None,
#    2147         sample_weight=sample_weight,
# -> 2148         zero_division=zero_division,
#    2149     )
#    2150     rows = zip(target_names, p, r, f1, s)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1551         sample_weight=sample_weight,
#    1552         labels=labels,
# -> 1553         samplewise=samplewise,
#    1554     )
#    1555     tp_sum = MCM[:, 1, 1]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in multilabel_confusion_matrix(y_true, y_pred, sample_weight, labels, samplewise)
#     504         le = LabelEncoder()
#     505         le.fit(labels)
# --> 506         y_true = le.transform(y_true)
#     507         y_pred = le.transform(y_pred)
#     508         sorted_labels = le.classes_
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in transform(self, y)
#     136             return np.array([])
#     137
# --> 138         return _encode(y, uniques=self.classes_)
#     139
#     140     def inverse_transform(self, y):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/_encode.py in _encode(values, uniques, check_unknown)
#     185             raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     186     else:
# --> 187         if check_unknown:
#     188             diff = _check_unknown(values, uniques)
#     189             if diff:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/_encode.py in _check_unknown(values, known_values, return_mask)
#     259                 valid_mask = np.ones(len(values), dtype=bool)
#     260
# --> 261         # check for nans in the known_values
#     262         if pandas_dtype.is_nan(known_values).any():
#     263             diff_is_nan = pandas_dtype.is_nan(diff)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import pandas as pd

# %%
cm = confusion_matrix(pred["y"].astype(str), pred["PredictedLabel"].astype(str))
plt.figure(figsize = (16, 9)) 
sns.heatmap(cm,cmap="Blues", annot=True, xticklabels = target_names, yticklabels = target_names )

# %%
model1 = XGBClassifier(n_estimators=304, reg_lambda=25)
model1.fit(X_train,y_train,eval_metric='merror')
y_pred_test1 = model1.predict(X_test)
#printing accuracy
print(f"accuracy: {accuracy_score(y_test,y_pred_test1)}")
print(f'New tuned model:\n {classification_report(pred["y"].astype(str), pred["PredictedLabel"].astype(str), labels=target_names)}')
# Out:
# accuracy: 0.0
# New tuned model:
#                precision    recall  f1-score   support
#
#        blues       0.00      0.00      0.00      10.0
#    classical       0.00      0.00      0.00      10.0
#      country       0.00      0.00      0.00      10.0
#        disco       0.00      0.00      0.00      10.0
#       hiphop       0.00      0.00      0.00      10.0
#         jazz       0.00      0.00      0.00      10.0
#        metal       0.00      0.00      0.00      10.0
#          pop       0.00      0.00      0.00      10.0
#       reggae       0.00      0.00      0.00      10.0
#         rock       0.00      0.00      0.00      10.0
#
#    micro avg       0.00      0.00      0.00     100.0
#    macro avg       0.00      0.00      0.00     100.0
# weighted avg       0.00      0.00      0.00     100.0

# %%
pickle.dump(sc, open('sc.pkl','wb'))
pickle.dump(model1, open('model.pkl', 'wb'))
